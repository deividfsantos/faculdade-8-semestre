# %%
import spacy.cli
import nltk

from pathlib import Path
from nltk import word_tokenize, pos_tag, ne_chunk

nltk.download('punkt')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('averaged_perceptron_tagger')

spacy.cli.download("en_core_web_sm")
#spacy.cli.download("en_core_web_md")
#spacy.cli.download("en_core_web_lg")

#Carregando o modelo e o texto
nlp = spacy.load("en_core_web_sm")
texto = "There were 70 children there. Preliminary findings were reported in today's New England Journal of Medicine. Earnings growth took a back seat. A small building in the back. A clear majority of senators back the bill. Enable the country to buy back debt. I was twenty-one back then."
doc = nlp(texto)
print(doc.text)
# Out:
# [nltk_data] Downloading package punkt to /home/deivid/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/deivid/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /home/deivid/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/deivid/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 16.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /home/deivid/.local/lib/python3.10/site-packages (from en-core-web-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.24.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.1)
# Requirement already satisfied: jinja2 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (67.6.1)
# Requirement already satisfied: packaging>=20.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/deivid/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.5.0)
# Requirement already satisfied: pydantic-core==2.4.0 in /home/deivid/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/deivid/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.6.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/deivid/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2020.6.20)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/deivid/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/deivid/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# There were 70 children there. Preliminary findings were reported in today's New England Journal of Medicine. Earnings growth took a back seat. A small building in the back. A clear majority of senators back the bill. Enable the country to buy back debt. I was twenty-one back then.

# %%
texto = "Washington was born into slavery on the farm of James Burroughs. Washington went up 2 games to 1 in the four-game series. Blair arrived in Washington for what may weçç be his last state visit. In June, Washington passed a primary seatbelt law."
doc = nlp(texto)
print(doc)

print("\nLista de labels do Spacy para entidades nomeadas:")
print(nlp.pipe_labels['ner'])
for label in nlp.pipe_labels['ner']:
  print(label, ' - ', spacy.explain(label))
print("\n(TOKEN, NER)")

for token in doc:
    print((token.text,  token.ent_type_ ))
# Out:
# Washington was born into slavery on the farm of James Burroughs. Washington went up 2 games to 1 in the four-game series. Blair arrived in Washington for what may weçç be his last state visit. In June, Washington passed a primary seatbelt law.
#
# Lista de labels do Spacy para entidades nomeadas:
# ['LOC', 'MISC', 'ORG', 'PER']
# LOC  -  Non-GPE locations, mountain ranges, bodies of water
# MISC  -  Miscellaneous entities, e.g. events, nationalities, products or works of art
# ORG  -  Companies, agencies, institutions, etc.
# PER  -  Named person or family.
#
# (TOKEN, NER)
# ('Washington', 'LOC')
# ('was', '')
# ('born', '')
# ('into', '')
# ('slavery', '')
# ('on', '')
# ('the', '')
# ('farm', '')
# ('of', '')
# ('James', 'PER')
# ('Burroughs', 'PER')
# ('.', '')
# ('Washington', 'MISC')
# ('went', 'MISC')
# ('up', 'MISC')
# ('2', 'MISC')
# ('games', 'MISC')
# ('to', 'MISC')
# ('1', 'MISC')
# ('in', 'MISC')
# ('the', '')
# ('four-game', '')
# ('series', '')
# ('.', '')
# ('Blair', 'MISC')
# ('arrived', 'MISC')
# ('in', 'MISC')
# ('Washington', '')
# ('for', '')
# ('what', '')
# ('may', '')
# ('weçç', '')
# ('be', '')
# ('his', '')
# ('last', '')
# ('state', '')
# ('visit', '')
# ('.', '')
# ('In', 'PER')
# ('June', 'PER')
# (',', '')
# ('Washington', 'LOC')
# ('passed', '')
# ('a', '')
# ('primary', 'LOC')
# ('seatbelt', 'LOC')
# ('law', '')
# ('.', '')

# %%
texto = "Washington was born into slavery on the farm of James Burroughs. Washington went up 2 games to 1 in the four-game series. Blair arrived in Washington for what may weçç be his last state visit. In June, Washington passed a primary seatbelt law."

# print("\nLista de labels do Spacy para entidades nomeadas:")
# print(nlp.pipe_labels['ner'])
# for label in nlp.pipe_labels['ner']:
#   print(label, ' - ', spacy.explain(label))
print("\n(TOKEN, NER)")

tokens = word_tokenize(texto)
print(tokens)
pos_tags = pos_tag(tokens)
print(pos_tags)
print("\n(NER TOKEN)")
named_entities = ne_chunk(pos_tags)
print(named_entities)
# Out:
# (TOKEN, NER)
# ['Washington', 'was', 'born', 'into', 'slavery', 'on', 'the', 'farm', 'of', 'James', 'Burroughs', '.', 'Washington', 'went', 'up', '2', 'games', 'to', '1', 'in', 'the', 'four-game', 'series', '.', 'Blair', 'arrived', 'in', 'Washington', 'for', 'what', 'may', 'weçç', 'be', 'his', 'last', 'state', 'visit', '.', 'In', 'June', ',', 'Washington', 'passed', 'a', 'primary', 'seatbelt', 'law', '.']
# [('Washington', 'NNP'), ('was', 'VBD'), ('born', 'VBN'), ('into', 'IN'), ('slavery', 'NN'), ('on', 'IN'), ('the', 'DT'), ('farm', 'NN'), ('of', 'IN'), ('James', 'NNP'), ('Burroughs', 'NNP'), ('.', '.'), ('Washington', 'NNP'), ('went', 'VBD'), ('up', 'RB'), ('2', 'CD'), ('games', 'NNS'), ('to', 'TO'), ('1', 'CD'), ('in', 'IN'), ('the', 'DT'), ('four-game', 'JJ'), ('series', 'NN'), ('.', '.'), ('Blair', 'NNP'), ('arrived', 'VBD'), ('in', 'IN'), ('Washington', 'NNP'), ('for', 'IN'), ('what', 'WP'), ('may', 'MD'), ('weçç', 'VB'), ('be', 'VB'), ('his', 'PRP$'), ('last', 'JJ'), ('state', 'NN'), ('visit', 'NN'), ('.', '.'), ('In', 'IN'), ('June', 'NNP'), (',', ','), ('Washington', 'NNP'), ('passed', 'VBD'), ('a', 'DT'), ('primary', 'JJ'), ('seatbelt', 'NN'), ('law', 'NN'), ('.', '.')]
# (S
#   (GPE Washington/NNP)
#   was/VBD
#   born/VBN
#   into/IN
#   slavery/NN
#   on/IN
#   the/DT
#   farm/NN
#   of/IN
#   (PERSON James/NNP Burroughs/NNP)
#   ./.
#   (GPE Washington/NNP)
#   went/VBD
#   up/RB
#   2/CD
#   games/NNS
#   to/TO
#   1/CD
#   in/IN
#   the/DT
#   four-game/JJ
#   series/NN
#   ./.
#   (PERSON Blair/NNP)
#   arrived/VBD
#   in/IN
#   (GPE Washington/NNP)
#   for/IN
#   what/WP
#   may/MD
#   weçç/VB
#   be/VB
#   his/PRP$
#   last/JJ
#   state/NN
#   visit/NN
#   ./.
#   In/IN
#   June/NNP
#   ,/,
#   (GPE Washington/NNP)
#   passed/VBD
#   a/DT
#   primary/JJ
#   seatbelt/NN
#   law/NN
#   ./.)

# %%
import spacy.cli
from pathlib import Path

spacy.cli.download("pt_core_news_sm")
nlp = spacy.load("pt_core_news_sm")
texto = "São Paulo foi um dos apóstolos de Cristo. Eu conheço São Paulo. Eu conheço a cidade de São Paulo. Eu já viajei para o estado de São Paulo. Eu queria estudar na USP. Ele fez CC na Universidade de São Paulo. São Paulo perdeu para o Internacional."
doc = nlp(texto)
print(doc.text)

for token in doc:
    print((token.text,  token.ent_type_ ))
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pt-core-news-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.6.0/pt_core_news_sm-3.6.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 5.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /home/deivid/.local/lib/python3.10/site-packages (from pt-core-news-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (1.24.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (2.1.1)
# Requirement already satisfied: jinja2 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (67.6.1)
# Requirement already satisfied: packaging>=20.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/deivid/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/deivid/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (0.5.0)
# Requirement already satisfied: pydantic-core==2.4.0 in /home/deivid/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/deivid/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (4.6.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/deivid/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (2020.6.20)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/deivid/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/deivid/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (0.1.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# São Paulo foi um dos apóstolos de Cristo. Eu conheço São Paulo. Eu conheço a cidade de São Paulo. Eu já viajei para o estado de São Paulo. Eu queria estudar na USP. Ele fez CC na Universidade de São Paulo. São Paulo perdeu para o Internacional.
# ('São', 'LOC')
# ('Paulo', 'LOC')
# ('foi', '')
# ('um', '')
# ('dos', '')
# ('apóstolos', '')
# ('de', '')
# ('Cristo', 'PER')
# ('.', '')
# ('Eu', '')
# ('conheço', '')
# ('São', 'LOC')
# ('Paulo', 'LOC')
# ('.', '')
# ('Eu', '')
# ('conheço', '')
# ('a', '')
# ('cidade', '')
# ('de', '')
# ('São', 'LOC')
# ('Paulo', 'LOC')
# ('.', '')
# ('Eu', '')
# ('já', '')
# ('viajei', '')
# ('para', '')
# ('o', '')
# ('estado', 'LOC')
# ('de', 'LOC')
# ('São', 'LOC')
# ('Paulo', 'LOC')
# ('.', '')
# ('Eu', '')
# ('queria', '')
# ('estudar', '')
# ('na', '')
# ('USP', 'LOC')
# ('.', '')
# ('Ele', '')
# ('fez', '')
# ('CC', '')
# ('na', '')
# ('Universidade', 'LOC')
# ('de', 'LOC')
# ('São', 'LOC')
# ('Paulo', 'LOC')
# ('.', '')
# ('São', 'LOC')
# ('Paulo', 'LOC')
# ('perdeu', '')
# ('para', '')
# ('o', '')
# ('Internacional', 'ORG')
# ('.', '')

# %%
nltk.download('floresta')  
texto = "São Paulo foi um dos apóstolos de Cristo. Eu conheço São Paulo. Eu conheço a cidade de São Paulo. Eu já viajei para o estado de São Paulo. Eu queria estudar na USP. Ele fez CC na Universidade de São Paulo. São Paulo perdeu para o Internacional."


tokens = word_tokenize(texto, language='portuguese')
print(tokens)
pos_tags = pos_tag(tokens)
print(pos_tags)
print("\n(NER TOKEN)")
named_entities = ne_chunk(pos_tags)
print(named_entities)
# Out:
# ['São', 'Paulo', 'foi', 'um', 'dos', 'apóstolos', 'de', 'Cristo', '.', 'Eu', 'conheço', 'São', 'Paulo', '.', 'Eu', 'conheço', 'a', 'cidade', 'de', 'São', 'Paulo', '.', 'Eu', 'já', 'viajei', 'para', 'o', 'estado', 'de', 'São', 'Paulo', '.', 'Eu', 'queria', 'estudar', 'na', 'USP', '.', 'Ele', 'fez', 'CC', 'na', 'Universidade', 'de', 'São', 'Paulo', '.', 'São', 'Paulo', 'perdeu', 'para', 'o', 'Internacional', '.']
# [('São', 'NNP'), ('Paulo', 'NNP'), ('foi', 'NN'), ('um', 'JJ'), ('dos', 'JJ'), ('apóstolos', 'NN'), ('de', 'IN'), ('Cristo', 'NNP'), ('.', '.'), ('Eu', 'NNP'), ('conheço', 'NN'), ('São', 'NNP'), ('Paulo', 'NNP'), ('.', '.'), ('Eu', 'NNP'), ('conheço', 'VBD'), ('a', 'DT'), ('cidade', 'NN'), ('de', 'IN'), ('São', 'NNP'), ('Paulo', 'NNP'), ('.', '.'), ('Eu', 'NNP'), ('já', 'NN'), ('viajei', 'NN'), ('para', 'NN'), ('o', 'JJ'), ('estado', 'NN'), ('de', 'IN'), ('São', 'NNP'), ('Paulo', 'NNP'), ('.', '.'), ('Eu', 'NNP'), ('queria', 'VBD'), ('estudar', 'FW'), ('na', 'JJ'), ('USP', 'NNP'), ('.', '.'), ('Ele', 'NNP'), ('fez', 'JJ'), ('CC', 'NNP'), ('na', 'FW'), ('Universidade', 'NNP'), ('de', 'FW'), ('São', 'NNP'), ('Paulo', 'NNP'), ('.', '.'), ('São', 'NNP'), ('Paulo', 'NNP'), ('perdeu', 'NN'), ('para', 'NN'), ('o', 'JJ'), ('Internacional', 'NNP'), ('.', '.')]
#
# (NER TOKEN)
# (S
#   (PERSON São/NNP)
#   (PERSON Paulo/NNP)
#   foi/NN
#   um/JJ
#   dos/JJ
#   apóstolos/NN
#   de/IN
#   (GPE Cristo/NNP)
#   ./.
#   (GPE Eu/NNP)
#   conheço/NN
#   (PERSON São/NNP Paulo/NNP)
#   ./.
#   (PERSON Eu/NNP)
#   conheço/VBD
#   a/DT
#   cidade/NN
#   de/IN
#   (PERSON São/NNP Paulo/NNP)
#   ./.
#   (GPE Eu/NNP)
#   já/NN
#   viajei/NN
#   para/NN
#   o/JJ
#   estado/NN
#   de/IN
#   (PERSON São/NNP Paulo/NNP)
#   ./.
#   (PERSON Eu/NNP)
#   queria/VBD
#   estudar/FW
#   na/JJ
#   (ORGANIZATION USP/NNP)
#   ./.
#   (PERSON Ele/NNP)
#   fez/JJ
#   CC/NNP
#   na/FW
#   (PERSON Universidade/NNP)
#   de/FW
#   (PERSON São/NNP Paulo/NNP)
#   ./.
#   (PERSON São/NNP Paulo/NNP)
#   perdeu/NN
#   para/NN
#   o/JJ
#   Internacional/NNP
#   ./.)
# [nltk_data] Downloading package floresta to /home/deivid/nltk_data...
# [nltk_data]   Package floresta is already up-to-date!
